# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar RGBA Fasat Charlie

# %%
RGBA_cube = np.load("RGBA/RGBA_0_2012-01-19T14_34_29.659347000_v1.npy")

# %%
RGBA_cube.shape
# Out:
# (8706, 7089, 4)

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(RGBA_cube, aspect = 'auto', interpolation = 'nearest')
plt.show()
